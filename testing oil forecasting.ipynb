# %%
import pandas as pd
import numpy as np

# %%
oil = pd.read_csv('data/testing_oil_forecast.csv')

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Columns: 119 entries, Date to % change
# dtypes: float64(118), object(1)
# memory usage: 470.5+ KB

# %%
oil.index = oil['Date']

# %%
oil = oil.drop(columns='Date')

# %%
# one week behind
slow_oil = oil[:"Jan 31, 2020"]

# %%
slow_oil
# Out:
#               price 1 week ahead  \
# Date
# Jun 04, 2010               77.18
# Jun 11, 2010               76.00
# Jun 18, 2010               72.14
# Jun 25, 2010               76.09
# Jul 02, 2010               76.01
# ...                          ...
# Nov 01, 2019               57.72
# Nov 08, 2019               57.77
# Nov 15, 2019               55.17
# Nov 22, 2019               59.20
# Nov 29, 2019               60.07
#
#               Weekly U.S. Refiner Net Input of Crude Oil  (Thousand Barrels per Day)  \
# Date
# Jun 04, 2010                                            15187.0
# Jun 11, 2010                                            15114.0
# Jun 18, 2010                                            15191.0
# Jun 25, 2010                                            15093.0
# Jul 02, 2010                                            15228.0
# ...                                                         ...
# Nov 01, 2019                                            15761.0
# ...

# %%
X = slow_oil.drop(columns='price 1 week ahead')
x = oil.drop(columns='price 1 week ahead')

# %%
Y = slow_oil['price 1 week ahead']
y = oil['price 1 week ahead']

# %%
correlation = oil.corr()['price 1 week ahead'].sort_values(ascending=False)

# %%
correlation = pd.DataFrame(correlation)

# %%
correlation.head(20)
# Out:
#                                                     price 1 week ahead
# price 1 week ahead                                            1.000000
# Weekly U.S. Ending Stocks of Conventional Motor...            0.694786
# Weekly U.S. Ending Stocks of Other Conventional...            0.694717
# Weekly U.S. Ending Stocks of Finished Motor Gas...            0.690590
# Weekly U.S.  Refiner and Blender Net Production...            0.587661
# Weekly U.S. Net Imports of Total Petroleum Prod...            0.582211
# Weekly U.S. Net Imports of Crude Oil and Petrol...            0.561654
# Weekly U.S. Ending Stocks of Distillate Fuel Oi...            0.519887
# Weekly U.S.  Refiner and Blender Net Production...            0.496542
# Weekly U.S. Refiner and Blender Net Production ...            0.492237
# Weekly U.S. Net Imports of Crude Oil  (Thousand...            0.483488
# Weekly U.S. Exports of Residual Fuel Oil  (Thou...            0.478795
# ...

# %%
info = oil.info()
info = pd.DataFrame(info)
info.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, Jun 04, 2010 to Feb 07, 2020
# Columns: 118 entries, price 1 week ahead to % change
# dtypes: float64(118)
# memory usage: 490.4+ KB
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()

# %%
knr.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
pred = knr.predict(X)

# %%
def forecast():
    cast = []
    for i in range(500):
        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)
        knr = KNeighborsRegressor()
        knr.fit(X_train, y_train)
        a = knr.predict(x)
        a = a[-1]
        cast.append(a)
    return cast

# %%
b = forecast()

# %%
np.mean(b)
# Out:
# 55.211803999999994

# %%
lists =(1,2,3,4,5)

# %%
lists[-2:]
# Out:
# (4, 5)

# %%
#testing

# %%
from sklearn import tree

# %%
def forecast():
    cast = []
    for i in range(500):
        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)
        mod = tree.DecisionTreeRegressor()
        mod.fit(X_train, y_train)
        a = mod.predict(x)
        a = a[-1]
        cast.append(a)
    return cast

# %%
d = forecast()

# %%
np.mean(d)
# Out:
# 56.24044
