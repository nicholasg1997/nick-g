# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
oil = pd.read_csv('data/crude_oil.csv')

# %%
oil.index = oil['Month']

# %%
oil['Month'] = pd.to_datetime(oil['Month'])
oil = oil.drop(columns='Month')

# %%
oil_1 = oil['2/1/2017':'2/1/2020']

# %%
oil_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 2/1/2017 to 2/1/2020
# Data columns (total 34 columns):
# futures price                      37 non-null float64
# Historical Price                   37 non-null float64
# monthly crude oil production       37 non-null float64
# all months                         37 non-null float64
# stock Level                        37 non-null float64
# Low                                37 non-null int64
# High                               37 non-null int64
# Range                              37 non-null int64
# total monthly production           37 non-null float64
# total monthly product supplied     37 non-null float64
# crude oil net imports              37 non-null float64
# product net imports                37 non-null float64
# product net exports                37 non-null float64
# total net imports                  37 non-null float64
# Distillate                         37 non-null float64
# ...

# %%
diff = oil_1.diff()
diff['Historical Price'] = diff.fillna(0)
oil_1['price change'] = diff['Historical Price']
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
features = ['monthly crude oil production','all months',
           'stock Level','High','Range','total monthly production',
           'total monthly product supplied','crude oil net imports',
            'total net imports','price change',
           'Distillate','monthly history','days of supply','stock level change',
           'gas/diss','product imp/exp','supp/prod','stock/days','heatin/cooling days']

# %%
features = ['Distillate', 'stock/days', 'stock Level',
           'days of supply','gas/diss', 'world production']

# %%
X = oil_1.loc[:, features]

# %%
y = oil_1['futures price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#K neighbours

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
pred = knn.predict(X)

# %%
pred = pd.DataFrame(pred)

# %%
X
# Out:
#            Distillate  stock/days  stock Level  days of supply  gas/diss  \
# Month
# 2/1/2017        162.8    8.184026        525.4            64.2  1.557648
# 3/1/2017        152.0    8.169855        538.6            65.9  1.575739
# 4/1/2017        155.0    8.091458        524.3            64.8  1.571475
# 5/1/2017        154.2    8.135448        516.8            63.5  1.572050
# 6/1/2017        152.1    7.908911        501.6            63.4  1.567914
# 7/1/2017        151.5    7.647227        483.4            63.2  1.537084
# 8/1/2017        147.8    7.267049        460.0            63.3  1.534363
# 9/1/2017        137.3    7.481626        469.6            62.8  1.625299
# 10/1/2017       130.1    7.618434        459.7            60.3  1.660062
# 11/1/2017       133.4    7.547835        453.1            60.0  1.686206
# 12/1/2017       145.6    6.992292        421.6            60.3  1.626059
# 1/1/2018        141.3    7.059666        420.8            59.6  1.760910
# ...

# %%
#difference
diff = diff.fillna(0)
diff['price change'] = diff['Historical Price']

# %%
results = ()
results= pd.DataFrame(results)
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=i)
    model = KNeighborsRegressor()
    model.fit(X_train, y_train)
    pred = model.predict(X)
    result = pd.DataFrame(pred)
    result = result.tail(1)
    results = pd.concat([result, results], ignore_index=True)

# %%
results.mean(axis=0)
# Out:
# 0    55.759478
# dtype: float64

# %%
from sklearn import svm

# %%
results = ()
results= pd.DataFrame(results)
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=i)
    model = svm.SVR()
    model.fit(X_train, y_train)
    pred = model.predict(X)
    result = pd.DataFrame(pred)
    result = result.tail(1)
    results = pd.concat([result, results], ignore_index=True)
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
results.mean(axis=0)
# Out:
# 0    55.339245
# dtype: float64

# %%
oil_1.corr()['futures price'].sort_values(ascending=False)
# Out:
# futures price                      1.000000
# Historical Price                   0.919713
# ho price                           0.886087
# rbob price                         0.761318
# gas/diss                           0.542931
# price change                       0.341964
# world production                   0.317903
# total monthly product supplied     0.253355
# monthly world production change    0.189458
# heatin/cooling days                0.155745
# world cosumption                   0.129450
# monthly history                    0.129447
# total monthly production           0.125969
# all months                         0.119121
# monthly crude oil production       0.119121
# crude/total imports                0.103263
# product net imports                0.086047
# Gasoline                           0.075397
# stock level change                 0.061084
# total net imports                  0.012627
# crude oil net imports             -0.020366
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 2/1/2017 to 2/1/2020
# Data columns (total 6 columns):
# Distillate          37 non-null float64
# stock/days          37 non-null float64
# stock Level         37 non-null float64
# days of supply      37 non-null float64
# gas/diss            37 non-null float64
# world production    37 non-null float64
# dtypes: float64(6)
# memory usage: 3.3+ KB

# %%
oil
# Out:
#            futures price  Historical Price  monthly crude oil production  \
# Month
# 1/1/2014           97.49             94.62                           NaN
# 2/1/2014          102.59            100.82                           NaN
# 3/1/2014          101.58            100.80                           NaN
# 4/1/2014           99.74            102.07                           NaN
# 5/1/2014          102.71            102.18                           NaN
# ...                  ...               ...                           ...
# 8/1/2020            0.00             55.50                         13.11
# 9/1/2020            0.00             56.50                         13.18
# 10/1/2020           0.00             57.50                         13.13
# 11/1/2020           0.00             58.50                         13.30
# 12/1/2020           0.00             59.50                         13.28
#
#            all months  stock Level  Low  High  Range  \
# Month
# ...

# %%
models = {
    'svr':svm.SVR(),
    'k_neigh':KNeighborsRegressor()
}

# %%
def fit_models(X,y):
    mfit={model: models[model].fit(X,y)
         for model in models.keys()}

# %%
fit_models(X_train,y_train)
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
models['svr'].predict(X)
# Out:
# array([54.11      , 53.96191453, 53.96184191, 53.96186492, 53.96191453,
#        53.96191453, 53.96191453, 54.96191624, 54.48      , 55.95930007,
#        54.99894503, 56.04502354, 56.0450237 , 54.96192079, 54.96663108,
#        54.96191468, 55.96191719, 55.96375967, 55.963757  , 54.96319022,
#        55.96191453, 54.93039845, 55.1518244 , 53.96210507, 55.04828691,
#        54.84432265, 55.94622169, 54.96191453, 55.95538029, 55.96174494,
#        55.        , 54.96199832, 54.28      , 54.41611943, 55.96191437,
#        53.96435539, 53.98418521])

# %%
def derive_positions(data):
    for model in models.keys():
        a = models[model].predict(data)

# %%
derive_positions(X)

# %%
results = ()
results= pd.DataFrame(results)
for model in models.keys():
    for i in range(100):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=i)
        mod = models[model]
        mod.fit(X_train, y_train)
        pred = mod.predict(X)
        result = pd.DataFrame(pred)
        result = result.tail(1)
        results = pd.concat([result, results], ignore_index=True)
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
results
# Out:
#              0
# 0    55.646000
# 1    56.798000
# 2    55.998000
# 3    56.172000
# 4    55.998000
# ..         ...
# 195  55.557456
# 196  55.536211
# 197  52.980597
# 198  55.706631
# 199  54.908211
#
# [200 rows x 1 columns]

# %%
a=results.head(100)
b=results.tail(100)

# %%
c=models.keys()

# %%
c={'strat_1':(),
  'strat_2':(),
  'range':()}
c = pd.DataFrame(c)

# %%
c['range'] = range(1,110)

# %%
c['strat_1'] = a

# %%
c['strat_2'] = b

# %%
c.set_index('range')
# Out:
#        strat_1    strat_2
# range
# 1       55.646        NaN
# 2       56.798        NaN
# 3       55.998        NaN
# 4       56.172        NaN
# 5       55.998        NaN
# ...        ...        ...
# 105        NaN  54.205455
# 106        NaN  54.671059
# 107        NaN  58.108027
# 108        NaN  56.797319
# 109        NaN  53.658196
#
# [109 rows x 2 columns]

# %%
c = c.append({'strat_1': a}, ignore_index=True)
c = c.append({'strat_2': b}, ignore_index=True)

# %%
a.mean(axis=0)
# Out:
# 0    55.75988
# dtype: float64

# %%
from sklearn.neural_network import MLPRegressor

# %%
def forecast():
    cast = []
    for model in models.keys():    
        for i in range(1000):
            mod = models[model]
            mod.fit(X_train, y_train)
            a = mod.predict(X)
            a = a[-1]
            cast.append(a)
    return cast

# %%
a = forecast()
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
models.keys()
# Out:
# dict_keys(['svr', 'k_neigh'])
