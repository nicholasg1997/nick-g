# %%
import pandas as pd
import numpy as np

# %%
oil = pd.read_csv('data/oil-data.csv')

# %%
oil.index = oil['date']

# %%
oil = oil.drop(columns='date')

# %%
oil
# Out:
#             Crude Oil  Commercial (Excluding SPR)  \
# date
# 10/25/2019    1080.51                      438.85
# 11/1/2019     1087.73                      446.78
# 11/8/2019     1088.51                      449.00
# 11/15/2019    1087.92                      450.38
# 11/22/2019    1088.12                      451.95
# 11/29/2019    1082.26                      447.10
# 12/6/2019     1082.89                      447.92
# 12/13/2019    1081.80                      446.83
# 12/20/2019    1076.33                      441.36
# 12/27/2019    1064.86                      429.90
# 1/3/2020      1066.03                      431.06
# 1/10/2020     1063.48                      428.51
# 1/17/2020     1063.07                      428.11
#
#             Strategic Petroleum Reserve (SPR)  Total Motor Gasoline  \
# date
# 10/25/2019                             641.65                220.06
# 11/1/2019                              640.95                217.23
# ...

# %%
x = oil.drop(columns='next week price')
X=x

# %%
y = oil['next week price']

# %%
correlation = oil.corr()['next week price'].sort_values(ascending=False)

# %%
correlation = pd.DataFrame(correlation)

# %%
correlation.tail(20)
# Out:
#                                    next week price
# Crude Oil                                 0.326603
# spr diff                                  0.142612
# Unfinished Oils                           0.128222
# tmg diff                                  0.052427
# Propane/Propylene                         0.022117
# > 15 ppm to 500 ppm sulfur                0.008215
# Other Oils                               -0.012395
# Reformulated                             -0.115075
# Strategic Petroleum Reserve (SPR)        -0.210429
# Blending Components                      -0.238951
# crude oil diff                           -0.247036
# Total Motor Gasoline                     -0.256966
# comm diff                                -0.256987
# Conventional                             -0.357056
# Distillate Fuel Oil                      -0.440533
# 15 ppm sulfur and Under                  -0.449126
# Fuel Ethanol                             -0.467267
# ...

# %%
oil['Crude Oil'].astype('float')
# Out:
# date
# 10/25/2019    1080.51
# 11/1/2019     1087.73
# 11/8/2019     1088.51
# 11/15/2019    1087.92
# 11/22/2019    1088.12
# 11/29/2019    1082.26
# 12/6/2019     1082.89
# 12/13/2019    1081.80
# 12/20/2019    1076.33
# 12/27/2019    1064.86
# 1/3/2020      1066.03
# 1/10/2020     1063.48
# 1/17/2020     1063.07
# Name: Crude Oil, dtype: float64

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 10/25/2019 to 1/17/2020
# Data columns (total 20 columns):
# Crude Oil                            13 non-null float64
# Commercial (Excluding SPR)           13 non-null float64
# Strategic Petroleum Reserve (SPR)    13 non-null float64
# Total Motor Gasoline                 13 non-null float64
# Reformulated                         13 non-null float64
# Conventional                         13 non-null float64
# Blending Components                  13 non-null float64
# Fuel Ethanol                         13 non-null float64
# Kerosene-Type Jet Fuel               13 non-null float64
# Distillate Fuel Oil                  13 non-null float64
# 15 ppm sulfur and Under              13 non-null float64
# > 15 ppm to 500 ppm sulfur           13 non-null float64
# > 500 ppm sulfur                     13 non-null float64
# Residual Fuel Oil                    13 non-null float64
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neural_network import MLPRegressor

# %%
mlp = MLPRegressor()

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_iter=200, momentum=0.9,
#              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#              random_state=None, shuffle=True, solver='adam', tol=0.0001,
#              validation_fraction=0.1, verbose=False, warm_start=False)

# %%
pred = mlp.predict(X)

# %%
def forecast():
    cast = []
    for i in range(5000):
        mlp = MLPRegressor()
        mlp.fit(X_train, y_train)
        a = mlp.predict(X)
        a = a[-1]
        cast.append(a)
    return cast

# %%
b = forecast()
# Out:
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\nickg\Miniconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...

# %%
np.mean(b)
# Out:
# 67.42658565591567
